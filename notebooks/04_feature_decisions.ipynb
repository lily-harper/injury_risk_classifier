# %%
from pathlib import Path
import os

PROJECT_ROOT = Path.cwd().parent

os.chdir(PROJECT_ROOT)
print("Project root:", PROJECT_ROOT)
print("Current working directory:", Path.cwd())
# Out:
# Project root: /Users/Local/REPOSITORIES/injury_risk_classifier
# Current working directory: /Users/Local/REPOSITORIES/injury_risk_classifier

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from pathlib import Path
import os 

# %load_ext autoreload
# %autoreload 2

from src.make_features import *

# %%
df = pd.read_csv("../injury_risk_classifier/data/interim/traffic_clean.csv")
df.head()
# Out:
#    Unnamed: 0    top_traffic_accident_offense                incident_address  \
# 0           0  TRAF - ACCIDENT                          I25 HWYNB / W 6TH AVE
# 1           1  TRAF - ACCIDENT                 E 17TH AVE / N PENNSYLVANIA ST
# 2           2  TRAF - ACCIDENT                          I25 HWYSB / PARK AVEW
# 3           3  TRAF - ACCIDENT - POLICE                   I25 HWYNB / 20TH ST
# 4           4  TRAF - ACCIDENT - HIT & RUN            W 37TH AVE / N PECOS ST
#
#       geo_lon    geo_lat       tu1_driver_action       tu2_driver_action  \
# 0 -105.013229  39.725677  No Contributing Action  No Contributing Action
# 1 -104.981084  39.743271     Failed to Yield ROW  No Contributing Action
# 2 -104.994972  39.768330    Followed Too Closely  No Contributing Action
# 3 -105.004334  39.760949    Followed Too Closely  No Contributing Action
# 4 -105.006450  39.768054                     NaN                     NaN
#
#               tu1_vehicle_type             tu2_vehicle_type  \
# 0     Pickup Truck/Utility Van                  Transit Bus
# 1  Passenger Car/Passenger Van                          SUV
# 2  Passenger Car/Passenger Van  Passenger Car/Passenger Van
# 3     Pickup Truck/Utility Van  Passenger Car/Passenger Van
# 4   Unknown (Hit and Run Only)  Passenger Car/Passenger Van
#
#      tu1_driver_humancontribfactor    tu2_driver_humancontribfactor  \
# 0  No Apparent Contributing Factor  No Apparent Contributing Factor
# 1  No Apparent Contributing Factor  No Apparent Contributing Factor
# 2  No Apparent Contributing Factor  No Apparent Contributing Factor
# 3               Aggressive Driving  No Apparent Contributing Factor
# 4                              NaN                              NaN
#
#   tu1_pedestrian_action  seriously_injured  fatalities tu2_pedestrian_action  \
# 0                   NaN                0.0         0.0                   NaN
# 1                   NaN                0.0         0.0                   NaN
# 2                   NaN                0.0         0.0                   NaN
# 3                   NaN                0.0         0.0                   NaN
# 4                   NaN                0.0         0.0                   NaN
#
#    road_description road_condition light_condition
# 0  Non-Intersection            Dry        Daylight
# 1   At Intersection            Dry        Daylight
# 2  Non-Intersection            Dry        Daylight
# 3  Non-Intersection            Dry    Dark-Lighted
# 4  Non-Intersection            Dry    Dark-Lighted

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'top_traffic_accident_offense', 'incident_address',
#        'geo_lon', 'geo_lat', 'tu1_driver_action', 'tu2_driver_action',
#        'tu1_vehicle_type', 'tu2_vehicle_type', 'tu1_driver_humancontribfactor',
#        'tu2_driver_humancontribfactor', 'tu1_pedestrian_action',
#        'seriously_injured', 'fatalities', 'tu2_pedestrian_action',
#        'road_description', 'road_condition', 'light_condition'],
#       dtype='str')

# %%
create_outcome(df)
# Out:
#         Unnamed: 0    top_traffic_accident_offense  \
# 0                0  TRAF - ACCIDENT
# 1                1  TRAF - ACCIDENT
# 2                2  TRAF - ACCIDENT
# 3                3  TRAF - ACCIDENT - POLICE
# 4                4  TRAF - ACCIDENT - HIT & RUN
# ...            ...                             ...
# 282353      282353  TRAF - ACCIDENT
# 282354      282354  TRAF - ACCIDENT - HIT & RUN
# 282355      282355  TRAF - ACCIDENT
# 282356      282356  TRAF - ACCIDENT - HIT & RUN
# 282357      282357  TRAF - ACCIDENT - HIT & RUN
#
#                       incident_address     geo_lon    geo_lat  \
# 0                I25 HWYNB / W 6TH AVE -105.013229  39.725677
# 1       E 17TH AVE / N PENNSYLVANIA ST -104.981084  39.743271
# 2                I25 HWYSB / PARK AVEW -104.994972  39.768330
# 3                  I25 HWYNB / 20TH ST -105.004334  39.760949
# 4              W 37TH AVE / N PECOS ST -105.006450  39.768054
# ...                                ...         ...        ...
# 282353          I25 HWYSB / W 23RD AVE -105.016793  39.751285
# 282354         I70 HWYWB / N MONACO ST -104.912882  39.778408
# 282355             50 BLOCK N HOLLY ST -104.922176  39.717045
# 282356           20TH ST / ARAPAHOE ST -104.990832  39.751590
# 282357                  5190 N GRAY ST -105.060105  39.790885
#
#               tu1_driver_action       tu2_driver_action  \
# 0        No Contributing Action  No Contributing Action
# 1           Failed to Yield ROW  No Contributing Action
# 2          Followed Too Closely  No Contributing Action
# 3          Followed Too Closely  No Contributing Action
# 4                           NaN                     NaN
# ...                         ...                     ...
# 282353           Lane Violation  No Contributing Action
# 282354         Careless Driving  No Contributing Action
# 282355     Followed Too Closely  No Contributing Action
# 282356           Lane Violation  No Contributing Action
# 282357  Too Fast for Conditions                     NaN
#
#                    tu1_vehicle_type             tu2_vehicle_type  \
# 0          Pickup Truck/Utility Van                  Transit Bus
# 1       Passenger Car/Passenger Van                          SUV
# 2       Passenger Car/Passenger Van  Passenger Car/Passenger Van
# 3          Pickup Truck/Utility Van  Passenger Car/Passenger Van
# 4        Unknown (Hit and Run Only)  Passenger Car/Passenger Van
# ...                             ...                          ...
# 282353  Passenger Car/Passenger Van  Passenger Car/Passenger Van
# 282354                          SUV     Pickup Truck/Utility Van
# 282355  Passenger Car/Passenger Van     Pickup Truck/Utility Van
# 282356  Passenger Car/Passenger Van  Passenger Car/Passenger Van
# 282357   Unknown (Hit and Run Only)                          NaN
#
#           tu1_driver_humancontribfactor    tu2_driver_humancontribfactor  \
# 0       No Apparent Contributing Factor  No Apparent Contributing Factor
# 1       No Apparent Contributing Factor  No Apparent Contributing Factor
# 2       No Apparent Contributing Factor  No Apparent Contributing Factor
# 3                    Aggressive Driving  No Apparent Contributing Factor
# 4                                   NaN                              NaN
# ...                                 ...                              ...
# 282353        Distracted/Other Interior  No Apparent Contributing Factor
# 282354               Aggressive Driving  No Apparent Contributing Factor
# 282355  No Apparent Contributing Factor  No Apparent Contributing Factor
# 282356  No Apparent Contributing Factor  No Apparent Contributing Factor
# 282357  No Apparent Contributing Factor                              NaN
#
#        tu1_pedestrian_action  seriously_injured  fatalities  \
# 0                        NaN                0.0         0.0
# 1                        NaN                0.0         0.0
# 2                        NaN                0.0         0.0
# 3                        NaN                0.0         0.0
# 4                        NaN                0.0         0.0
# ...                      ...                ...         ...
# 282353                   NaN                0.0         0.0
# 282354                   NaN                0.0         0.0
# 282355                   NaN                0.0         0.0
# 282356                   NaN                0.0         0.0
# 282357                   NaN                0.0         0.0
#
#        tu2_pedestrian_action  road_description  \
# 0                        NaN  Non-Intersection
# 1                        NaN   At Intersection
# 2                        NaN  Non-Intersection
# 3                        NaN  Non-Intersection
# 4                        NaN  Non-Intersection
# ...                      ...               ...
# 282353                   NaN   At Intersection
# 282354                   NaN  Non-Intersection
# 282355                   NaN  Non-Intersection
# 282356                   NaN   At Intersection
# 282357                   NaN  Non-Intersection
#
#                           road_condition light_condition  injured
# 0                                    Dry        Daylight        0
# 1                                    Dry        Daylight        0
# 2                                    Dry        Daylight        0
# 3                                    Dry    Dark-Lighted        0
# 4                                    Dry    Dark-Lighted        0
# ...                                  ...             ...      ...
# 282353                               Dry        Daylight        0
# 282354                               Dry        Daylight        0
# 282355                               Wet        Daylight        0
# 282356                               Dry    Dark-Lighted        0
# 282357  Icy W/Visible Icy Road Treatment        Daylight        0
#
# [282358 rows x 19 columns]
